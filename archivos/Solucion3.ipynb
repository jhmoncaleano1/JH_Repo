# %%
import pandas as pd
df = pd.read_csv("datos_solucion.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#               Nombre                     cargo    Departamento  Salario
# 0       Ana Lívia S.   Técnico de Producción I          Ventas     3520
# 1    Leticia Barbosa  Ingeniero de Software II  Administrativo    11902
# 2          Antonella    Diretor Administrativo      Producción    17600
# 3              David      Analista Comercial I              TI     5400
# 4             Louise   Técnico de Producción I          Ventas     4840
# ..               ...                       ...             ...      ...
# 202         Victoria   Técnico de Producción I          Ventas     3520
# 203            Luisa     Analista Comercial II              TI     7500
# 204      Ana Cecília   Técnico de Producción I          Ventas     3740
# 205         Marta J.  Técnico de Producción II          Ventas     6160
# 206        Marcelo R  Técnico de Producción II          Ventas     5940
#
# [207 rows x 4 columns]

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Departamento', y='Salario')
plt.title('Distribución de Salarios por Departamento')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
salario_por_departamento.plot(kind='bar', color='skyblue')
plt.title("Salario total por Departamento")
plt.xlabel("Departamento")
plt.ylabel("Salario Total")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 salario_por_departamento.plot(kind='bar', color='skyblue')
#       3 plt.title("Salario total por Departamento")
#       4 plt.xlabel("Departamento")
#
# NameError: name 'salario_por_departamento' is not defined

# %%
plt.figure(figsize=(8,8))
salario_por_departamento.plot(kind='pie', autopct='%1.1f%%', startangle=140, cmap='tab20')
plt.title("Distribución porcentual del salario por Departamento")
plt.ylabel("")  # Quitar el label automático
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 plt.figure(figsize=(8,8))
# ----> 2 salario_por_departamento.plot(kind='pie', autopct='%1.1f%%', startangle=140, cmap='tab20')
#       3 plt.title("Distribución porcentual del salario por Departamento")
#       4 plt.ylabel("")  # Quitar el label automático
#
# NameError: name 'salario_por_departamento' is not defined
